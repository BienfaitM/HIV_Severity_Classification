# %%
# %run last_table.ipynb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ['baselineRNA']
# ['baselineRNA']
# ['baselineCD4']
# ['drug', 'drugClass']
# ['baselineNewTreatment']
# ['baselineIsolate', 'relativetDate', 'nucleotideSequence']
# ['aaMutation']
# ['followupRNA']
# ['followupCD4']
# ['pastRegimenTreatments']
# ['pastRNA']
# ['pastCD4']
# ['pastIsolate', 'nucleotideSequence']
# ['patient']
# ['baselineYear']
# []
# ['baselineRNA', 'relativeDate', 'logLoad', 'rawLoad']
# ['baselineRNA', 'relativeDate', 'rawLoad']
# ['baselineCD4', 'relativeDate', 'count']
# ['drug']
# ['baselineNewTreatment', 'relativeStartDate', 'relativeStopDate', 'duration']
# ['baselineIsolate', 'relativetDate']
# ['aaMutation', 'position']
# ['followupRNA', 'relativeDate', 'logLoad', 'rawLoad']
# ['followupCD4', 'relativeDate', 'count']
# ['pastRegimenTreatments', 'relativeStartDate', 'relativeStopDate', 'duration']
# ['pastRNA', 'relativeDate', 'logLoad', 'rawLoad']
# ['pastCD4', 'relativeDate', 'count']
# ...

# %%
import pandas as pd
import numpy as np
import torch

# %%
final
# Out:
#       CD4NadirBeforeTCE  BaselineCD4Count  pastrawLoad  pastCD4count  \
# 0                     5               100         1000            40
# 1                   267               296        15849             5
# 2                   296               369         3981           164
# 3                    19                19        19953           156
# 4                   106               207        15849           472
# ...                 ...               ...          ...           ...
# 1531                 50               101          501            51
# 1532                213               403           79           112
# 1533                224               247         3981           244
# 1534                  9                81         5012            88
# 1535                151               207         1995           416
#
#       BaselineRNAlog
# 0                  0
# 1                  1
# 2                  0
# 3                  1
# 4                  0
# ...

# %%
final_copy = final.copy()

# %%
final
# Out:
#       CD4NadirBeforeTCE  BaselineCD4Count  pastrawLoad  pastCD4count  \
# 0                     5               100         1000            40
# 1                   267               296        15849             5
# 2                   296               369         3981           164
# 3                    19                19        19953           156
# 4                   106               207        15849           472
# ...                 ...               ...          ...           ...
# 1531                 50               101          501            51
# 1532                213               403           79           112
# 1533                224               247         3981           244
# 1534                  9                81         5012            88
# 1535                151               207         1995           416
#
#       BaselineRNAlog
# 0                  0
# 1                  1
# 2                  0
# 3                  1
# 4                  0
# ...

# %%
final_copy = final.copy()

# %%
null_col = [col for col in final_copy
           if final_copy[col].isna().any()]
null_col
# Out:
# []

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
y = final_copy['BaselineRNAlog']
X = final_copy.drop(['BaselineRNAlog'], axis = 1)

# %%
y = pd.DataFrame(y, columns = ['BaselineRNAlog'])
y
# Out:
#       BaselineRNAlog
# 0                  0
# 1                  1
# 2                  0
# 3                  1
# 4                  0
# ...              ...
# 1531               0
# 1532               1
# 1533               1
# 1534               1
# 1535               0
#
# [1516 rows x 1 columns]

# %%
X
# Out:
#       CD4NadirBeforeTCE  BaselineCD4Count  pastrawLoad  pastCD4count
# 0                     5               100         1000            40
# 1                   267               296        15849             5
# 2                   296               369         3981           164
# 3                    19                19        19953           156
# 4                   106               207        15849           472
# ...                 ...               ...          ...           ...
# 1531                 50               101          501            51
# 1532                213               403           79           112
# 1533                224               247         3981           244
# 1534                  9                81         5012            88
# 1535                151               207         1995           416
#
# [1516 rows x 4 columns]

# %% [markdown]
# # Standardization

# %%
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
scaler_transform = (scaler.transform(X))
scaler_transform
# Out:
# array([[-1.0433021 , -0.96295819, -0.26904034, -1.34010951],
#        [ 0.97377943,  0.01935292, -0.12737008, -1.4959953 ],
#        [ 1.19704418,  0.38521369, -0.24059943, -0.78782844],
#        ...,
#        [ 0.6427317 , -0.22622486, -0.24059943, -0.43151807],
#        [-1.01250696, -1.05818223, -0.23076294, -1.12632329],
#        [ 0.08072043, -0.42669651, -0.25954732,  0.33454923]])

# %%
scaler_transform_data = pd.DataFrame(scaler_transform , columns = ['CD4NadirBeforeTCE','BaselineCD4Count','pastrawLoad','pastCD4count'])
scaler_transform_data
# Out:
#       CD4NadirBeforeTCE  BaselineCD4Count  pastrawLoad  pastCD4count
# 0             -1.043302         -0.962958    -0.269040     -1.340110
# 1              0.973779          0.019353    -0.127370     -1.495995
# 2              1.197044          0.385214    -0.240599     -0.787828
# 3             -0.935519         -1.368913    -0.088215     -0.823459
# 4             -0.265725         -0.426697    -0.127370      0.583966
# ...                 ...               ...          ...           ...
# 1511          -0.696857         -0.957946    -0.273801     -1.291117
# 1512           0.558045          0.555615    -0.277827     -1.019430
# 1513           0.642732         -0.226225    -0.240599     -0.431518
# 1514          -1.012507         -1.058182    -0.230763     -1.126323
# 1515           0.080720         -0.426697    -0.259547      0.334549
#
# [1516 rows x 4 columns]

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 3)
pc_s = pca.fit_transform(scaler_transform_data)
pc_s
# pca_data = pd.DataFrame(pc_s,columns = ['PC1','PC2','PC3'])
# final_data = pd.concat([pca_data, y], axis =1)
# Out:
# array([[-1.5076792 , -0.56500755, -1.13629626],
#        [ 0.59003417, -0.43356425, -1.46606606],
#        [ 1.06331812, -0.38847275, -0.79047333],
#        ...,
#        [ 0.26941451, -0.32946127, -0.37390233],
#        [-1.53778446, -0.48539748, -0.92887258],
#        [-0.20863804, -0.19429535,  0.4120311 ]])

# %%
# final_data = final_data.dropna()
# final_data

# %%
y = final_copy['BaselineRNAlog']
X = final_copy.drop(['BaselineRNAlog'], axis = 1)
y = pd.DataFrame(y, columns =['BaselineRNAlog'])

# %%
final_copy.values
# Out:
# array([[    5,   100,  1000,    40,     0],
#        [  267,   296, 15849,     5,     1],
#        [  296,   369,  3981,   164,     0],
#        ...,
#        [  224,   247,  3981,   244,     1],
#        [    9,    81,  5012,    88,     1],
#        [  151,   207,  1995,   416,     0]])

# %%
X1 = final_copy.values[:,:-1]
X1
# Out:
# array([[    5,   100,  1000,    40],
#        [  267,   296, 15849,     5],
#        [  296,   369,  3981,   164],
#        ...,
#        [  224,   247,  3981,   244],
#        [    9,    81,  5012,    88],
#        [  151,   207,  1995,   416]])

# %%
y1 = final_copy.values[::,-1]
y1
# Out:
# array([0, 1, 0, ..., 1, 1, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
# X_train, X_test, y_train, y_test = train_test_split(X1,y1,test_size = 0.4, random_state = 0)
# X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42)

# %%
# for i in [X_train,X_test, X_valid]:
#     print(round(len(i) / len(y), 2))

# %%
# for i in [y_train, y_test, y_valid]:
#     print(round(len(i)/ len(y), 2))

# %%
final_copy.shape
# Out:
# (1516, 5)

# %% [markdown]
# # Train test valid test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X1,y1,test_size = 0.4, random_state = 0)
X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42)

# %%
for i in [X_train,X_test, X_valid]:
    print(round(len(i) / len(y), 2))
# Out:
# 0.6
# 0.2
# 0.2

# %%
for i in [y_train, y_test, y_valid]:
    print(round(len(i)/ len(y), 2))
# Out:
# 0.6
# 0.2
# 0.2

# %%
BATCH_SIZE = 64

torch_X_train = torch.from_numpy(X_train).type(torch.LongTensor)
torch_y_train = torch.from_numpy(y_train).type(torch.LongTensor)

torch_X_test =  torch.from_numpy(X_test).type(torch.LongTensor)
torch_y_test =  torch.from_numpy(y_test).type(torch.LongTensor)

torch_X_valid = torch.from_numpy(X_valid).type(torch.LongTensor)
torch_y_valid = torch.from_numpy(y_valid).type(torch.LongTensor)

train = torch.utils.data.TensorDataset(torch_X_train, torch_y_train)
test  = torch.utils.data.TensorDataset(torch_X_test, torch_y_test)
val   = torch.utils.data.TensorDataset(torch_X_valid, torch_y_valid)

train_loader = torch.utils.data.DataLoader(train, batch_size = BATCH_SIZE, shuffle = False)
test_loader  = torch.utils.data.DataLoader(test,  batch_size = BATCH_SIZE, shuffle = False)
valid_loader = torch.utils.data.DataLoader(val,   batch_size = BATCH_SIZE, shuffle = False)

# %%
for data, target in train_loader: break
print(data.shape)
print(target.shape)
# Out:
# torch.Size([64, 4])
# torch.Size([64])

# %%
for data,target in train_loader:break
data
# Out:
# tensor([[   111,    111,    200,    230],
#         [   462,    703,  15849,    654],
#         [   133,    485,     79,    804],
#         [   160,    730,  50119,    488],
#         [   273,    492,     79,    335],
#         [   260,    489,  12589,     99],
#         [   448,    573,   7943,     86],
#         [     4,    106, 158489,     11],
#         [   289,    550, 158489,    940],
#         [   204,    460,    501,    324],
#         [   108,    108,  10000,    123],
#         [   280,    420,   5012,    687],
#         [   185,    510,  12589,    360],
#         [   251,    460, 125893,    210],
#         [   434,    573,   2512,   1052],
#         [   116,    272,     79,     88],
#         [    60,    242,    501,    150],
#         [   339,    644,    398,    165],
#         [    10,    230,  31623,    783],
#         [    22,    169, 251189,    310],
#         [   210,    511,     50,    204],
#         [     3,      3,    200,    508],
# ...

# %%
for data, target in test_loader: break
print(data.dtype)
print(target.dtype)
# Out:
# torch.int64
# torch.int64

# %%
torch_X_train = torch_X_train.view(-1, 1).float()
torch_X_test = torch_X_test.view(-1,1).float()
print(torch_X_train.shape)
print(torch_X_test.shape)
# Out:
# torch.Size([3636, 1])
# torch.Size([1216, 1])

# %%
for batch_idx, (X_batch, y_batch) in enumerate(train_loader):
    print(batch_idx,X_batch.shape,y_batch.shape)
# Out:
# 0 torch.Size([64, 4]) torch.Size([64])
# 1 torch.Size([64, 4]) torch.Size([64])
# 2 torch.Size([64, 4]) torch.Size([64])
# 3 torch.Size([64, 4]) torch.Size([64])
# 4 torch.Size([64, 4]) torch.Size([64])
# 5 torch.Size([64, 4]) torch.Size([64])
# 6 torch.Size([64, 4]) torch.Size([64])
# 7 torch.Size([64, 4]) torch.Size([64])
# 8 torch.Size([64, 4]) torch.Size([64])
# 9 torch.Size([64, 4]) torch.Size([64])
# 10 torch.Size([64, 4]) torch.Size([64])
# 11 torch.Size([64, 4]) torch.Size([64])
# 12 torch.Size([64, 4]) torch.Size([64])
# 13 torch.Size([64, 4]) torch.Size([64])
# 14 torch.Size([13, 4]) torch.Size([13])

# %%
from torchvision import transforms 
import torch
from torch import nn, optim
import torch.nn.functional as F

class Classifier(nn.Module):
    def __init__(self,input_features=4,hidden1=20,hidden2=20,out_features=2):
        super().__init__()
        self.f_connected1=nn.Linear(input_features,hidden1)
        self.f_connected2=nn.Linear(hidden1,hidden2)
        self.out=nn.Linear(hidden2,out_features)
    def forward(self,x):
        x=F.relu(self.f_connected1(x))
        x=F.relu(self.f_connected2(x))
        x=self.out(x)
        return x

# class Classifier(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(4,20)
#         self.fc2 = nn.Linear(20,20)
#         self.fc3 = nn.Linear(20,20)
#         self.fc4 = nn.Linear(20,2)
#     def forward(self, x):
#         x = x.view(x.size(0), -1)
        
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = F.relu(self.fc3(x))
#         x = F.log_softmax(self.fc4(x), dim =1)
        
#         return x
    
#     def num_flat_features(self, x):
#         size = x.size()[1:]  # all dimensions except the batch dimension
#         num_features = 1
#         for s in size:
#             num_features *= s
#         return num_features

# %%
model = Classifier()

# %%
model
# Out:
# Classifier(
#   (f_connected1): Linear(in_features=4, out_features=20, bias=True)
#   (f_connected2): Linear(in_features=20, out_features=20, bias=True)
#   (out): Linear(in_features=20, out_features=2, bias=True)
# )

# %%
for p in model.parameters():
    print(p.shape)
# Out:
# torch.Size([20, 4])
# torch.Size([20])
# torch.Size([20, 20])
# torch.Size([20])
# torch.Size([2, 20])
# torch.Size([2])

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.003)
epochs = 500
features, labels = next(iter(test_loader))

# %%
# for e in range(epochs):
#     running_loss = 0
#     for features, label in train_loader:
#         features = features.float()
#         log_ps = model(features)
#         loss = criterion(log_ps,labels)
        
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
        
#         running_loss += loss.item()
        
#     else:
#         print(f"train loss:{running_loss / len(train_loader)}")

# %%
X_train  =torch.FloatTensor(X_train)
X_test   =torch.FloatTensor(X_test)
y_train  =torch.LongTensor(y_train)
y_test   =torch.LongTensor(y_test)

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.001) #lr=0.001
error = nn.CrossEntropyLoss()
EPOCHS = 50

# %%
model = Classifier()
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.003)

epochs=500
final_losses=[]
for i in range(epochs):
    i=i+1
    optimizer.zero_grad()

    y_pred=model.forward(X_train)
    loss=loss_function(y_pred,y_train)
    final_losses.append(loss)
    if i%10==1:
        print("Epoch number: {} and the loss : {}".format(i,loss.item()))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Epoch number: 1 and the loss : 841.2033081054688
# Epoch number: 11 and the loss : 69.68094635009766
# Epoch number: 21 and the loss : 27.896352767944336
# Epoch number: 31 and the loss : 14.429221153259277
# Epoch number: 41 and the loss : 19.945404052734375
# Epoch number: 51 and the loss : 3.95674204826355
# Epoch number: 61 and the loss : 9.944336891174316
# Epoch number: 71 and the loss : 10.236140251159668
# Epoch number: 81 and the loss : 9.841407775878906
# Epoch number: 91 and the loss : 13.66408920288086
# Epoch number: 101 and the loss : 7.58086633682251
# Epoch number: 111 and the loss : 7.167996883392334
# Epoch number: 121 and the loss : 2.7163703441619873
# Epoch number: 131 and the loss : 10.424317359924316
# Epoch number: 141 and the loss : 13.778552055358887
# Epoch number: 151 and the loss : 3.8739259243011475
# Epoch number: 161 and the loss : 4.243128776550293
# Epoch number: 171 and the loss : 8.27819538116455
# ...

# %%
def fit(model, train_loader):
    model.train()
    for epoch in range(EPOCHS):
        correct = 0
        for batch_idx, (X_batch, y_batch) in enumerate(train_loader):
            X_batch = X_batch.float()           
            optimizer.zero_grad()
            output = model(X_batch)
            loss = error(output, y_batch)
            loss.backward()
            optimizer.step()
            # Total correct predictions
            predicted = torch.max(output.data, 1)[1] 
            correct += (predicted == y_batch).sum()
            if batch_idx % 50 == 0:
                print('Epoch : {},\t Loss {} \t Accuracy:{:.3f}%'.format(epoch, loss.item(), correct*100/float(BATCH_SIZE*(batch_idx+1))))

# %%
fit = model(Classifier,train_loader)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-4c9c1041e147> in <module>
# ----> 1 fit = model(Classifier,train_loader)
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# TypeError: forward() takes 2 positional arguments but 3 were given

# %%
model = Classifier()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.003)

epochs = 30
steps = 0

train_losses, test_losses = [], []
for e in range(epochs):
    running_loss = 0
    for data,target in train_loader:
        optimizer.zero_grad()
        data = data.float()
        log_ps = model(data)
        loss = criterion(log_ps,data)
        loss.backward()
        optimizer.step()
        
        running_loss +=loss.item()
    else:
        test_loss = 0
        accuracy  = 0
        with torch.no_grad():
            for data,target in test_loader:
                log_ps = model(target)
                test_loss += criterion(log_ps, data)
                
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy += torch.mean(equals.type(torch.FloatTensor))
        model.train()
        train_losses.append(running_loss/len(X_train))
        test_losses.append(test_loss/len(X_test))

        print("Epoch: {}/{}.. ".format(e+1, epochs),
              "Training Loss: {:.3f}.. ".format(train_losses[-1]),
              "Test Loss: {:.3f}.. ".format(test_losses[-1]),
              "Test Accuracy: {:.3f}".format(accuracy/len(testloader)))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-56-47ec89031fcc> in <module>
#      13         data = data.float()
#      14         log_ps = model(data)
# ---> 15         loss = criterion(log_ps,data)
#      16         loss.backward()
#      17         optimizer.step()
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     945
#     946     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# ...

# %%
# X_train = X_train.to_numpy()
# X_test =  X_test.to_numpy()
# X_val = X_val.to_numpy()

# y_train = y_train.to_numpy()
# y_test  = y_test.to_numpy()
# y_val   = y_val.to_numpy()

# %% [markdown]
# # ANN Model

# %%
# from torchvision import transforms 
# import torch
# from torch import nn, optim
# import torch.nn.functional as F

# %%
# BATCH_SIZE = 64

# torch_X_train = torch.from_numpy(X_train.values).type(torch.LongTensor)
# torch_y_train = torch.from_numpy(y_train.values).type(torch.LongTensor)

# torch_X_test =  torch.from_numpy(X_test.values).type(torch.LongTensor)
# torch_y_test =  torch.from_numpy(y_test.values).type(torch.LongTensor)

# torch_X_valid = torch.from_numpy(X_val.values).type(torch.LongTensor)
# torch_y_valid = torch.from_numpy(y_val.values).type(torch.LongTensor)

# train = torch.utils.data.TensorDataset(torch_X_train, torch_y_train)
# test  = torch.utils.data.TensorDataset(torch_X_test, torch_y_test)
# val   = torch.utils.data.TensorDataset(torch_X_valid, torch_y_valid)

# train_loader = torch.utils.data.DataLoader(train, batch_size = BATCH_SIZE, shuffle = False)
# test_loader  = torch.utils.data.DataLoader(test,  batch_size = BATCH_SIZE, shuffle = False)
# valid_loader = torch.utils.data.DataLoader(val,   batch_size = BATCH_SIZE, shuffle = False)

# %%
# from torchvision import transforms
# import torch
# from torch import nn, optim
# import torch.nn.functional as F

# %%
# BATCH_SIZE = 32

# torch_X_train = torch.from_numpy(X_train).type(torch.LongTensor)
# torch_y_train = torch.from_numpy(y_train).type(torch.LongTensor)



# torch_X_test  = torch.from_numpy(X_test).type(torch.LongTensor)
# torch_y_test  = torch.from_numpy(y_test).type(torch.LongTensor)

# train = torch.utils.data.TensorDataset(torch_X_train,torch_y_train)
# test =  torch.utils.data.TensorDataset(torch_X_test,torch_y_test)

# # data loader
# train_loader = torch.utils.data.DataLoader(train, batch_size = BATCH_SIZE, shuffle = False)
# test_loader =  torch.utils.data.DataLoader(test, batch_size = BATCH_SIZE, shuffle = False)

# %%
# for data, target in train_loader: break
# print(data.shape)
# print(target.shape)

# %%
# torch_X_train = torch_X_train.view(-1,1,28,28).float()
# torch_X_test  = torch_X_test.view(-1,1,28,28).float()
# print(torch_X_train.shape)
# print(torch_X_test.shape)

# %%
# # Pytorch train and test sets
# train = torch.utils.data.TensorDataset(torch_X_train,torch_y_train)
# test = torch.utils.data.TensorDataset(torch_X_test,torch_y_test)

# # data loader
# train_loader = torch.utils.data.DataLoader(train, batch_size = BATCH_SIZE, shuffle = False)
# test_loader = torch.utils.data.DataLoader(test, batch_size = BATCH_SIZE, shuffle = False)

# %%
# for batch_idx, (X_batch, y_batch) in enumerate(train_loader):
#     print(batch_idx,X_batch.shape,y_batch.shape)

# %%
# # TODO: Define your network architecture here
# class Classifier(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(784, 256)
#         self.fc2 = nn.Linear(256, 128)
#         self.fc3 = nn.Linear(128, 64)
#         self.fc4 = nn.Linear(64, 10)
        
#     def forward(self, x):
#         # make sure input tensor is flattened
#         x = x.view(x.shape[0], -1)
        
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = F.relu(self.fc3(x))
#         x = F.log_softmax(self.fc4(x), dim=1)
        
#         return x

# #     def num_flat_features(self, x):
# #         size = x.size()[1:]  # all dimensions except the batch dimension
# #         num_features = 1
# #         for s in size:
# #             num_features *= s
# #         return num_features

# %%
# model = Classifier()

# %%
# model

# %%
# for p in model.parameters():
#     print(p.shape)

# %%
# # TODO: Create the network, define the criterion and optimizer
# model = Classifier()
# criterion = nn.MSELoss()
# optimizer = optim.Adam(model.parameters(), lr=0.003)

# %%
# # TODO: Train the network here
# epochs = 5

# for e in range(epochs):
#     running_loss = 0
#     for X, labels in train_loader:
#         log_ps = model(X)
#         loss = criterion(log_ps, labels.long())
        
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
        
#         running_loss += loss.item()
#     else:
#         print(f"Training loss: {running_loss/len(trainloader)}")
